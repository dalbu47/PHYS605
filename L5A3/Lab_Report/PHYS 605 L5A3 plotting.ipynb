# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

filelist = os.listdir(path='CSV_Data')

#print(filelist)
data = []
for i in range(len(filelist)):
    file_path = f'CSV_Data/{filelist[i]}'
    read = pd.read_csv(file_path, comment='#', encoding='latin1')
    data.append(read)
    print(f"{filelist[i]}:")
    display(data[i].head())
# Out:
# L5A3AmpBode1.csv:
#    Frequency (Hz)  Channel 2 Magnitude (dB)  Channel 2 Phase (°)
# 0        9.892000                 20.925187            -0.013537
# 1       11.374644                 20.925656            -0.011891
# 2       13.079511                 20.925454            -0.005360
# 3       15.039909                 20.926021            -0.003914
# 4       17.294137                 20.925838            -0.016938
# L5A3AmpGain1.csv:
#    Frequency (Hz)  Channel 2 Magnitude (X)  Channel 2 Phase (°)
# 0        9.892000                11.124887             0.000120
# 1       11.374644                11.125830            -0.007948
# 2       13.079511                11.123886            -0.005930
# 3       15.039909                11.125003            -0.008395
# 4       17.294137                11.124136            -0.008644
# L5A3p1FunkyTriangleWave.csv:
#    Time (s)  Channel 1 (V)  Math 1 (V)
# 0  0.000347       0.061283   -0.341540
# 1  0.000348       0.060952   -0.397813
# ...

# %%
for i in [0, 1, 6, 8]:
    filelist[i] = 'Magnitude'
for i in [7,9]:
    filelist[i] = 'Magnitude (Stable)'
for i in [2,3]:
    filelist[i] = 'Triangle Wave (1kHz, 100mV)'
for i in [4,5]:
    filelist[i] = 'Sine Wave (100kHz, 20mV)'
for i in [10,11]:
    filelist[i] = 'Triangle Wave (100kHz, 20mV)'
for i in range(len(data)):
    file_name = filelist[i]
    plt.figure(figsize=(12, 6))

    num_columns = len(data[i].columns)

    if num_columns == 3: # for 3 column data files
        if data[i].columns[2] == 'Channel 2 Phase (°)':
            # Plot bode and phase separately from voltage
            plt.figure(figsize=(10, 6))
            plt.plot(data[i].iloc[:, 0], data[i].iloc[:, 1], label=data[i].columns[1])
            plt.xscale('log')
            plt.title(f'Plot for {file_name}')
            plt.xlabel(data[i].columns[0])
            plt.ylabel(data[i].columns[1])
            plt.legend()
            plt.figure(figsize=(10,6))
            plt.plot(data[i].iloc[:, 0], data[i].iloc[:, 2], color='g', label=data[i].columns[2])
            plt.title(f'Phase Plot for {file_name}')
            plt.xlabel(data[i].columns[0])
            plt.ylabel("Phase (deg)")
            plt.legend()
        else:
            # Plot for Voltage
            plt.plot(data[i].iloc[:, 0], data[i].iloc[:, 1], label=data[i].columns[1])
            plt.plot(data[i].iloc[:, 0], data[i].iloc[:, 2], label=data[i].columns[2])
            plt.title(f'Voltage Plot for {file_name}')
            plt.xlabel(data[i].columns[0])
            plt.ylabel("Voltage (V)")
            plt.legend()

    elif num_columns == 4: # for 4 column data files
            # Voltage and Amp Plot
        if data[i].columns[3] == 'Math 1 (V)':
            plt.figure(figsize=(10, 6))
            plt.plot(data[i].iloc[:, 0], data[i].iloc[:, 1], label=data[i].columns[1])
            plt.plot(data[i].iloc[:, 0], data[i].iloc[:, 3], label=data[i].columns[3])
            plt.xscale('log')
            plt.title(f'Voltage Plot for {file_name}')
            plt.xlabel(data[i].columns[0])
            plt.ylabel(data[i].columns[2])
            plt.legend()
               
        else:
            # Bode and Gain + Phase Plot
            plt.figure(figsize=(10, 6))
            #plt.plot(data[i].iloc[:, 0], data[i].iloc[:, 1], label=data[i].columns[1])
            plt.plot(data[i].iloc[:, 0], data[i].iloc[:, 2], label=data[i].columns[2])
            plt.xscale('log')
            plt.title(f'Plot for {file_name}')
            plt.xlabel(data[i].columns[0])
            plt.ylabel(data[i].columns[2])
            plt.legend()
        
            plt.figure(figsize=(10, 6))
            plt.plot(data[i].iloc[:, 0], data[i].iloc[:, 3], color='g', label=data[i].columns[3])
            plt.xscale('log')
            plt.title(f'Phase Plot for {file_name}')
            plt.xlabel(data[i].columns[0])
            plt.ylabel("Phase (deg)")
            plt.legend()

        plt.tight_layout()

    plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(data[2].iloc[:, 0]-(data[2].iloc[:, 0] - data[3].iloc[:, 0]), data[2].iloc[:, 2], color='red',label=f'Unstable {filelist[2]}')
plt.plot(data[3].iloc[:, 0], data[3].iloc[:, 3], color='cyan',label=f'Stable {filelist[2]}')
#plt.xscale('log')
plt.title(f'Comparison of stable and unstable plots for {filelist[2]}')
plt.xlabel(data[2].columns[0])
plt.ylabel('Voltage (V)')
plt.legend()

plt.figure(figsize=(12,6))
plt.plot(data[4].iloc[:, 0]-(data[4].iloc[:, 0] - data[5].iloc[:, 0]), data[4].iloc[:, 3], color='red',label=f'Unstable {filelist[4]}')
plt.plot(data[5].iloc[:, 0], data[5].iloc[:, 3], color='cyan',label=f'Stable {filelist[4]}')
#plt.xscale('log')
plt.title(f'Comparison of stable and unstable plots for {filelist[4]}')
plt.xlabel(data[2].columns[0])
plt.ylabel('Voltage (V)')
plt.legend()

plt.figure(figsize=(12,6))
plt.plot(data[6].iloc[:, 0], data[6].iloc[:, 2], color='red',label='Unstable Bode')
plt.plot(data[7].iloc[:, 0], data[7].iloc[:, 2], color='cyan',label='Stable Bode')
plt.xscale('log')
plt.title('Comparison of stable and unstable Bode plots')
plt.xlabel(data[6].columns[0])
plt.ylabel('Magnitude(dB)')
plt.legend()

plt.figure(figsize=(12,6))
plt.plot(data[8].iloc[:, 0], data[8].iloc[:, 2], color='red', label='Unstable Gain')
plt.plot(data[9].iloc[:, 0], data[9].iloc[:, 2], color='cyan', label='Stable Gain')
plt.xscale('log')
plt.title('Comparison of stable and unstable Gain plots')
plt.xlabel(data[8].columns[0])
plt.ylabel('Gain(X)')
plt.legend()

plt.figure(figsize=(12,6))
plt.plot(data[10].iloc[:, 0]-(data[10].iloc[:, 0] - data[11].iloc[:, 0]), data[10].iloc[:, 2], color='red',label=f'Unstable {filelist[10]}')
plt.plot(data[11].iloc[:, 0], data[11].iloc[:, 3], color='cyan',label=f'Stable {filelist[10]}')
#plt.xscale('log')
plt.title(f'Comparison of stable and unstable plots for {filelist[10]}')
plt.xlabel(data[10].columns[0])
plt.ylabel('Voltage (V)')
plt.legend()
